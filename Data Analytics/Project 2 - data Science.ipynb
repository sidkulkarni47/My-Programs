# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv("/Users/siddhantkulkarni/Downloads/500_Person_Gender_Height_Weight_Index.csv")

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
data.tail()
# Out:
#      Gender  Height  Weight  Index
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5

# %%
data.describe()
# Out:
#            Height      Weight       Index
# count  500.000000  500.000000  500.000000
# mean   169.944000  106.000000    3.748000
# std     16.375261   32.382607    1.355053
# min    140.000000   50.000000    0.000000
# 25%    156.000000   80.000000    3.000000
# 50%    170.500000  106.000000    4.000000
# 75%    184.000000  136.000000    5.000000
# max    199.000000  160.000000    5.000000

# %%
from sklearn import svm
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
gender = LabelEncoder()
data['Gender'] = gender.fit_transform(data['Gender'])

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0       1     174      96      4
# 1       1     189      87      2
# 2       0     185     110      4
# 3       0     195     104      3
# 4       1     149      61      3

# %%
bins = (-1,0,1,2,3,4,5)
health = ['malnourished', 'underweight', 'fit', 'slightly overweight', 'overweight', 'extremely overweight']
data['Index'] = pd.cut(data['Index'], bins = bins, labels= health)

# %%
data['Index']
# Out:
# 0                overweight
# 1                       fit
# 2                overweight
# 3       slightly overweight
# 4       slightly overweight
#                ...
# 495    extremely overweight
# 496              overweight
# 497    extremely overweight
# 498    extremely overweight
# 499    extremely overweight
# Name: Index, Length: 500, dtype: category
# Categories (6, object): ['malnourished' < 'underweight' < 'fit' < 'slightly overweight' < 'overweight' < 'extremely overweight']

# %%
data['Gender'].value_counts()
# Out:
# 0    255
# 1    245
# Name: Gender, dtype: int64

# %%
sns.countplot(data['Index'])
# Out:
# /Users/siddhantkulkarni/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Index', ylabel='count'>

# %%
sns.relplot(x='Height', y='Weight', hue='Index', data = data)

# %%
sns.relplot(x='Index', y='Weight', hue='Gender', kind ='line', data = data, height = 5, aspect = 3)

# %%
sns.relplot(x='Index', y='Height', hue='Gender', kind ='line', data = data, height = 5, aspect = 3)

# %%
x = data.drop('Index', axis=1)
y = data['Index']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler

s = StandardScaler()
X_train_scaled = s.fit_transform(X_train)
X_test_scaled = s.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/b9/54z882sj403g2lvbbnzz2gc00000gn/T/ipykernel_3411/985113278.py in <module>
#       2
#       3 s = StandardScaler()
# ----> 4 X_train_scaled = s.fit_transform(X_train)
#       5 X_test_scaled = s.transform(X_test)
#
# NameError: name 'X_train' is not defined
